# %%
import pandas as pd
import numpy as np

# %%
dataframe=pd.read_csv('dataset_Facebook.csv',';')

# %%
dataframe
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
dataframe.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
dataframe['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
photos=dataframe[dataframe['Type'] == 'Photo']
photos
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
videos = dataframe[dataframe['Type']=='Video']
videos
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
media_posts=pd.concat([videos,photos])
media_posts
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
media_posts.sort_values('like')
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 76             137893  Photo         1          11             3          2
# 417            104070  Photo         1           3             3         10
# 441             98195  Photo         1           3             5          4
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %% [markdown]
# media_posts.transpose()

# %%
media_posts.transpose()
# Out:
#                                                        29      55      71   \
# Page total likes                                    138895  138329  137893
# Type                                                 Video   Video   Video
# Category                                                 1       1       1
# Post Month                                              12      11      11
# Post Weekday                                             4       6       5
# Post Hour                                               11       2       3
# Paid                                                   1.0     1.0     1.0
# Lifetime Post Total Reach                            36208   16416  100768
# Lifetime Post Total Impressions                      61262   31950  220447
# Lifetime Engaged Users                                1141     459    2101
# Lifetime Post Consumers                               1068     411    1735
# ...

# %%
reshaped = pd.melt(media_posts, 
                       id_vars='Type', 
                       value_vars=['comment','like','share'],
                       var_name='Engagement', 
                       value_name='Popularity')

# %%
reshaped
# Out:
#        Type Engagement  Popularity
# 0     Video    comment        18.0
# 1     Video    comment         2.0
# 2     Video    comment        17.0
# 3     Video    comment         2.0
# 4     Video    comment         6.0
# ...     ...        ...         ...
# 1294  Photo      share        26.0
# 1295  Photo      share        22.0
# 1296  Photo      share        18.0
# 1297  Photo      share        38.0
# 1298  Photo      share        28.0
#
# [1299 rows x 3 columns]
